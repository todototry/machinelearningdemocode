# %%
# pandas的数据处理 与 sklearn的数据预处理结合
# 1. 数据集的装载
# 2. 特征列的分析
# 3.

# %%
"""pandas 
1.特定列的选择
2.指定坐标对应值得修改
3.指定条件的行筛选
4.删除指定列
5.增加特定列
6.增加一行
7.删除一行。 
"""

# %%
#Pandas
#1. 针对特征列数据的统计学分析
#2. 针对特征列的可视化方法 matpltlib , seaborn

# %%
# sklearn.preprocessing
# 
# 
 
#![title](img/sklearn_preprocessing.jpg)
from IPython.display import Image
Image("img/sklearn_preprocessing.jpg")
